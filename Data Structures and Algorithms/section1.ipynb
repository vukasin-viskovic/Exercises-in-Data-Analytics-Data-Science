# %%
{
    "tags": [
        "hide-input",
    ]
}

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(101)

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, x)
