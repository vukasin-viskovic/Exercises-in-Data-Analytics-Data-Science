# %% [markdown]
# # Python S10 Pandas Built-in Data Visualization
#
# ## My Course Notes and Code
#
# These are my notes from the Jose Portilla's Udemy course available [here](https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/).
#
# I'm focusing on the section 9 of the course, which deals with **Pandas Built-in Data Visualization**.
#
# **Pandas** allows us to visualize data quickly and easily. However, for more complex data visualization, and in situations when we need more controle over the properties of our visualizations, we should use **Matplotlib** or **Seaborn** instead.

# %% [markdown]
# ____
# ### S10V56 Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

df1 = pd.read_csv('C:\\Users\\PC\\Desktop\\Python\\Udemy - P for DS and ML Bootcamp\\07-Pandas-Built-in-Data-Viz\\df1.csv', 
index_col = 0,          # important
parse_dates=True)       # important

df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('C:\\Users\\PC\\Desktop\\Python\\Udemy - P for DS and ML Bootcamp\\07-Pandas-Built-in-Data-Viz\\df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.set(rc={"figure.dpi":100, 'savefig.dpi':100})   

df1['A'].hist(bins = 30)

# %%
df1['A'].plot(kind = 'hist')

# %%
df1['A'].plot.hist()

# %% [markdown]
# #### Different Plot Types

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# #### Area plot

# %%
df2.plot.area(alpha = 0.4)

# %% [markdown]
# #### Bar plot

# %%
df2.plot.bar()

# %%
df2.plot.bar().legend(bbox_to_anchor=(0.38, 0.95))

# %% [markdown]
# You can also use the bbox_to_anchor() argument to place the legend outside of the plot. For example, you can use the following syntax to place the legend in the top right corner outside of the plot:
#
# `plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)`
#
# Cited from: [statology.org](https://www.statology.org/seaborn-legend-position/#:~:text=To%20change%20the%20position%20of%20a%20legend%20in%20a%20seaborn,legend()%20command.&text=The%20default%20location%20is%20%E2%80%9Cbest,avoids%20covering%20any%20data%20points.)
#
# Another useful link:
# http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas

# %%
df2.plot.bar().legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
df2.plot.bar(stacked = True).legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# #### Histogram

# %%
df1['A'].plot.hist(bins = 30)

# %% [markdown]
# #### Lineplot

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq=None)

# %%
df1.plot.line(y = 'B', figsize = (12, 3), lw = 1)

# %% [markdown]
# #### Scatterplot

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm')

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C']*100, edgecolors='black', alpha = 0.8)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# C:\Users\PC\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### Boxplot

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])
df.head()
# Out:
#           a         b
# 0 -0.296405 -1.789605
# 1  1.769582 -0.884333
# 2  2.030089 -1.565237
# 3  0.230180 -0.364439
# 4 -0.532298  0.143653

# %% [markdown]
# #### Hexabin plot

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 25, cmap = 'coolwarm')

# %% [markdown]
# #### KDE plot

# %%
df2['a'].plot.kde() #` df2['a'].plot.density()`

# %%
df2.plot.kde() #` df2['a'].plot.density()`

# %% [markdown]
# ____
# ### S10V57 Exercises

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

import seaborn as sns
sns.set_style('darkgrid')
sns.set(rc={"figure.dpi":100, 'savefig.dpi':100}) 

df3 = pd.read_csv('C:\\Users\\PC\\Desktop\\Python\\Udemy - P for DS and ML Bootcamp\\07-Pandas-Built-in-Data-Viz\\df3.csv')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.plot.scatter(x = 'b', y = 'a', figsize = (12, 3), color = 'red', edgecolor = 'black', s = 50)

# %%
plt.style.use('ggplot')
df3['a'].hist(bins = 30, alpha = 0.5)

# %%
df3[['a', 'b']].plot.box()

# %%
df3['d'].plot.density(lw = 3, ls = '--') # Not much sense in making kde line dashed, just for practice

# %%
df3[df3.index <= 30].plot.area(alpha = 0.7).legend(bbox_to_anchor=(1.0, 1.0))

# %%
# ose's solution:

f = plt.figure()
df3.iloc[0:30].plot.area(alpha=0.4)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# the `loc` argument doesn't make a difference when `bbox_to_anchor` is added
